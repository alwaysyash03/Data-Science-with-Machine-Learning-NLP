# %%
## Class
class Car:
    pass
audi = Car()
bmw = Car()
print(type(audi))
# Out:
# <class '__main__.Car'>

# %%
print(audi)
print(bmw)
# Out:
# <__main__.Car object at 0x7eac3a6eb8f0>
# <__main__.Car object at 0x7eac3a6eab40>

# %%
audi.window = 4  ## window = Attribute
print(audi.window)
# Out:
# 4

# %%
### Instance variables and Methods
class Dog:
    ##constructor
    def __init__(self, name, age):
        self.name = name ## name = instance variable
        self.age = age   ## age = instance variable

## Create objects
dog1 = Dog("Buddy", 2)
print(dog1)   
print(dog1.name)
print(dog1.age)
# Out:
# <__main__.Dog object at 0x7eac3a6f96d0>
# Buddy
# 2

# %%
dog2 = Dog("Charlie", 3)
print(dog2.name)
print(dog2.age)
# Out:
# Charlie
# 3

# %%
## Define a  class with Instance method
class Dog:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def bark(self):
        print(f"{self.name} says Woof!")    

dog1 = Dog("Buddy", 2)
dog1.bark()      
dog2 = Dog("Charlie", 3)
dog2.bark()
# Out:
# Buddy says Woof!
# Charlie says Woof!

# %%
### Modeling a Bank Account

## Define a class for bank account
class BankAccount:
    def __init__(self, owner, balance=0):
        self.owner = owner
        self.balance = balance

    def deposit(self, amount):
        self.balance += amount
        print(f"Deposited {amount}. New balance: {self.balance}")  

    def withdraw(self, amount):
        if amount > self.balance:
            print("Insufficient funds")
        else:
            self.balance -= amount
            print(f"Withdrew {amount}. New balance: {self.balance}")

    def get_balance(self):
        return self.balance


## Create an account
account = BankAccount("Yash", 5000)
print(account.balance)
# Out:
# 5000

# %%
## Call instance methods
account.deposit(1500)
# Out:
# Deposited 1500. New balance: 6500

# %%
account.withdraw(2000)
# Out:
# Withdrew 2000. New balance: 4500

# %%
account.get_balance()
# Out:
# 4500
